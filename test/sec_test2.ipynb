# %% [markdown]
# testing

# %%
from edgar import *
set_identity("dattasohamai@gmail.com")

# %%
company = Company("MSFT")
filing = company.get_filings(form = ['10-K'])

# %%
finance = company.get_financials()

# %%
income = finance.income_statement(view='detailed')
income_statement = income.to_dataframe().iloc[:,:8]
print(income_statement.to_markdown())
# Out:
# |    | concept                                                                                             | label                                                | standard_concept               |   2025-06-30 (FY) |   2024-06-30 (FY) |   2023-06-30 (FY) |   level | abstract   |
# |---:|:----------------------------------------------------------------------------------------------------|:-----------------------------------------------------|:-------------------------------|------------------:|------------------:|------------------:|--------:|:-----------|
# |  0 | us-gaap_RevenueFromContractWithCustomerExcludingAssessedTax                                         | Revenue                                              | Revenue                        |       2.81724e+11 |       2.45122e+11 |       2.11915e+11 |       4 | False      |
# ...

# %%
quarterly_finance = company.
